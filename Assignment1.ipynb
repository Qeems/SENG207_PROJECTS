# %% [markdown]
# <h1 style = 'text-align :center'> PROJECT1 ( DATA ANALYSIS)</h1>

# %% [markdown]
# ## NAME : AWUDU HAKIM BANSI
# ## ID : 10966622
# ## Department: Materials Science and Engineering

# %% [markdown]
# ## Introduction
# Dataset of all inventories of 'CHATEU DE MERE' Wine manufacturing Company.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
# Data set
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ## DATASET PREPROCESSING

# %%
# looking for uncompleted inventories
data.isnull().any().any()
# Out:
# True

# %% [markdown]
# #### Some inventories are missing certain parameters

# %%
# Deleting all incomplete inventories
data.dropna(inplace = True)

# %% [markdown]
# #### Deleting all incomplete inventories would ensure that complete dataset is used for the analysis. This will improve the efficacy of our results.

# %%
# deleting all duplicates in the dataset
data = data.drop_duplicates()

# %%
# Renaming the colomns
data = data.rename(columns= {'fixed acidity' : 'fixed_acidity', 'volatile acidity' : 'volatile_acidity', 'citric acid' : 'citric_acid', 'residual sugar' : 'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide', 'total sulfur dioxide':'total_sulfur_dioxide'})

# %%
data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed_acidity         1591 non-null   float64
#  2   volatile_acidity      1591 non-null   float64
#  3   citric_acid           1591 non-null   float64
#  4   residual_sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free_sulfur_dioxide   1591 non-null   float64
#  7   total_sulfur_dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %% [markdown]
# #### From the Data info, nine incompleted entries have been taken off. We are now going to analyze 1591 sets of data out of 1600

# %%
data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed_acidity         1591 non-null   float64
#  2   volatile_acidity      1591 non-null   float64
#  3   citric_acid           1591 non-null   float64
#  4   residual_sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free_sulfur_dioxide   1591 non-null   float64
#  7   total_sulfur_dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %% [markdown]
# ### Statistical inferences of the entire dataset

# %%
df= data.loc[0:1601, ['fixed_acidity','volatile_acidity', 'citric_acid','residual_sugar', 'chlorides','free_sulfur_dioxide','total_sulfur_dioxide', 'density','pH','sulphates','alcohol','quality']]
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1591.000000       1591.000000  1591.000000     1591.000000
# mean        8.320616          0.527681     0.271477        2.540761
# std         1.740134          0.179045     0.194807        1.413076
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1591.000000          1591.000000           1591.000000  1591.000000
# mean      0.087500            15.861722             46.498429     0.996747
# std       0.047175            10.429385             32.998659     0.001889
# ...

# %% [markdown]
# #### As it can be seen clearly in the dataset above, there is a huge difference between the 75th percentile and maximum values of free_sulfur_dioxide and tota_sulfur_dioxide.

# %%
for col in df.columns.values:
    print('Number of unique values of {} : {}'.format(col, df[col].nunique()))
# Out:
# Number of unique values of fixed_acidity : 96
# Number of unique values of volatile_acidity : 143
# Number of unique values of citric_acid : 80
# Number of unique values of residual_sugar : 91
# Number of unique values of chlorides : 153
# Number of unique values of free_sulfur_dioxide : 60
# Number of unique values of total_sulfur_dioxide : 144
# Number of unique values of density : 434
# Number of unique values of pH : 89
# Number of unique values of sulphates : 96
# Number of unique values of alcohol : 65
# Number of unique values of quality : 6

# %% [markdown]
# #### From the data above, the unique values for each of the quantitative compositions can clearly be seen. The feature has a maximum unique value is density and the minimum unique value is quality.

# %%
plt.figure(figsize=(12,4), dpi= 300)
p= sns.scatterplot(data= df, palette= 'Dark2')
p.set(xlabel="Sample", ylabel = "Element concetration")
plt.show()

# %%
D= sns.histplot(data= df, bins =10 , binwidth=5, element= 'poly')
D.set(xlabel="quantitative composition", ylabel = "Total number ")
plt.show()

# %% [markdown]
# ### FIXED ACIDITY

# %%
data.fixed_acidity.describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed_acidity, dtype: float64

# %%
fixed_acidity_mean = data.fixed_acidity.mean()
y = data.fixed_acidity < fixed_acidity_mean
y.value_counts()
# Out:
# True     965
# False    626
# Name: fixed_acidity, dtype: int64

# %%
lb = ['Below fixed_acidity_mean','Above fixed_acidity_mean']
explode = [0,0.1]
color_values = ['y', 'b']
plt.pie(y.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below fixed_acidity_mean, Above fixed_acidity_mean')
plt.legend(y.value_counts())

# %%
E= sns.histplot(data= data.fixed_acidity, kde= True)
E.set(xlabel="fixed acidity", ylabel = "sample or ID")
plt.show()

# %% [markdown]
# #### There are high number of samples with a fixed acidity of 7 and 8 with low samples of fixed acidity of 12 to 16.

# %% [markdown]
# ### VOLATILE  ACIDITY

# %%
data.volatile_acidity.describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile_acidity, dtype: float64

# %%
volatile_acidity_mean = data.volatile_acidity.mean()
z = data.volatile_acidity < volatile_acidity_mean
z.value_counts()
# Out:
# True     812
# False    779
# Name: volatile_acidity, dtype: int64

# %%
lb = ['Below volatile_acidity_mean','Above volatile_acidity_mean']
explode = [0,0.1]
color_values = ['y', 'r']
plt.pie(z.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below volatile_acidity_mean, Above volatile_acidity_mean')
plt.legend(z.value_counts())

# %%
plt.hist(data.volatile_acidity)
plt.ylabel('Count')
plt.xlabel('volatile_acidity')
# Out:
# Text(0.5, 0, 'volatile_acidity')

# %%
sns.histplot(data= data.volatile_acidity, kde= True, bins = 20)
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Count'>

# %% [markdown]
# #### from the Chart, it can be seen that there is a high number of samples with a volatile acidity of 0.4 and 0.6 with very few samples having a volatile acidity from 1.1 tp 1.6.

# %% [markdown]
# ### CITRIC ACID

# %%
data.citric_acid.describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric_acid, dtype: float64

# %%
citric_acid_mean = data.citric_acid.mean()
p = data.citric_acid < citric_acid_mean
p.value_counts()
# Out:
# True     847
# False    744
# Name: citric_acid, dtype: int64

# %%
lb = ['Below citric_acid_mean','Above citric_acid_mean']
explode = [0,0.1]
color_values = ['g', 'b']
plt.pie(p.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below citric_acid_mean, Above citric_acid_mean')
plt.legend(p.value_counts())

# %%
plt.hist(data.citric_acid)
plt.ylabel('Count')
plt.xlabel('citric_acid')
# Out:
# Text(0.5, 0, 'citric_acid')

# %%
sns.histplot(data= data.citric_acid, kde= True, bins = 20)
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %% [markdown]
# #### From the histogram, there are quite a good number of wine with a citric acid content of 0.1 and least wine samples of 0.8 and 1.0

# %% [markdown]
# ### RESIDUAL SUGAR

# %%
data.residual_sugar.describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual_sugar, dtype: float64

# %%
residual_sugar_mean = data.residual_sugar.mean()
q = data.residual_sugar < residual_sugar_mean
q.value_counts()
# Out:
# True     1156
# False     435
# Name: residual_sugar, dtype: int64

# %%
lb = ['Below','Above']
explode = [0,0.1]
color_values = ['m', 'b']
plt.pie(q.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below residual_sugar_mean, Above residual_sugar_mean')
plt.legend(q.value_counts())

# %%
plt.hist(data.residual_sugar)
plt.ylabel('Count')
plt.xlabel('residual_sugar')
# Out:
# Text(0.5, 0, 'residual_sugar')

# %%
sns.histplot(data= data.residual_sugar, kde= True, bins = 20)
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %% [markdown]
# #### A huge number of the wine sample have a high residual content of 2.

# %% [markdown]
# ### CHLORIDES

# %%
data.chlorides.describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
chlorides_mean = data.chlorides.mean()
r = data.chlorides < chlorides_mean
r.value_counts()
# Out:
# True     1120
# False     471
# Name: chlorides, dtype: int64

# %%
lb = ['Below','Above']
explode = [0,0.1]
color_values = ['y', 'b']
plt.pie(r.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below chlorides_mean, Above chlorides_mean')
plt.legend(r.value_counts())

# %%
plt.hist(data.chlorides)
plt.ylabel('Count')
plt.xlabel('chlorides')
# Out:
# Text(0.5, 0, 'chlorides')

# %%
sns.histplot(data= data.chlorides, kde= True, bins = 20)
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %% [markdown]
# #### Most of the wine have a high chloride content of 0.1

# %% [markdown]
# ### SULFUR DIOXIDE

# %%
data.free_sulfur_dioxide.describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free_sulfur_dioxide, dtype: float64

# %%
free_sulfur_dioxide_mean = data.free_sulfur_dioxide.mean()
w = data.free_sulfur_dioxide < free_sulfur_dioxide_mean
w.value_counts()
# Out:
# True     918
# False    673
# Name: free_sulfur_dioxide, dtype: int64

# %%
lb = ['Below','Above']
explode = [0,0.1]
color_values = ['r', 'm']
plt.pie(w.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below free_sulfur_dioxide_mean, Above free_sulfur_dioxide_mean')
plt.legend(w.value_counts())

# %%
plt.hist(data.free_sulfur_dioxide)
plt.ylabel('Index')
plt.xlabel(' free sulfur dioxide')
# Out:
# Text(0.5, 0, ' free sulfur dioxide')

# %%
sns.histplot(data= data.free_sulfur_dioxide, kde= True, bins = 20)
# Out:
# <Axes: xlabel='free_sulfur_dioxide', ylabel='Count'>

# %% [markdown]
# #### Most of the wine samples have a high free sulphur dioxide content between 5 and 7

# %% [markdown]
# ### DENSITY

# %%
data.density.describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
density_mean = data.density.mean()
f = data.density < density_mean
f.value_counts()
# Out:
# False    796
# True     795
# Name: density, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['y', 'm']
plt.pie(f.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below density_mean, Above density_mean')
plt.legend(f.value_counts())

# %%
plt.hist(data.density)
plt.ylabel('Index')
plt.xlabel('density')
# Out:
# Text(0.5, 0, 'density')

# %% [markdown]
# #### As from the graph, most of the wine samples have a high density of 0.996

# %% [markdown]
# ### PH

# %%
sns.histplot(data= data.density, kde= True, bins = 20)

# %%
data.pH.describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
pH_mean = data.pH.mean()
g = data.pH < pH_mean
g.value_counts()
# Out:
# True     817
# False    774
# Name: pH, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['y', 'm']
plt.pie(g.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below pH_mean, Above pH_mean')
plt.legend(g.value_counts())

# %%
plt.hist(data.pH)
plt.ylabel('Index')
plt.xlabel('pH')
# Out:
# Text(0.5, 0, 'pH')

# %%
sns.histplot(data= data.pH, kde= True, bins = 20)
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %% [markdown]
# #### From the graph, it can be observed that most of the winne samples have a high PH of 3.5.

# %% [markdown]
# ### SULPHATES

# %%
data.sulphates.describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
sulphates_mean = data.sulphates.mean()
h = data.sulphates < sulphates_mean
h.value_counts()
# Out:
# True     956
# False    635
# Name: sulphates, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['c', 'b']
plt.pie(g.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below sulphates_mean, Above sulphates_mean')
plt.legend(g.value_counts())

# %%
plt.hist(data.sulphates)
plt.ylabel('Index')
plt.xlabel('sulphates')
# Out:
# Text(0.5, 0, 'sulphates')

# %%
sns.histplot(data= data.sulphates, kde= True, bins = 20)
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %% [markdown]
# #### From the graph above, most of the wine samples have a high sulphate content between 0.5 and 0.75

# %% [markdown]
# ### ALCOHOL

# %%
data.alcohol.describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
alcohol_mean = data.alcohol.mean()
i = data.alcohol < alcohol_mean
i.value_counts()
# Out:
# True     910
# False    681
# Name: alcohol, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['y', 'c']
plt.pie(i.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below alcohol_mean, Above alcohol_mean')
plt.legend(i.value_counts())

# %%
plt.hist(data.alcohol)
plt.ylabel('Index')
plt.xlabel('alcohol')
# Out:
# Text(0.5, 0, 'alcohol')

# %%
sns.histplot(data= data.alcohol, kde= True, bins = 20)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# #### Most of the samples have a high alcohol content of about 9.5.

# %% [markdown]
# ### QUALITY

# %%
data.quality.describe()

# %%
quality_mean = data.quality.mean()
x = data.quality < quality_mean
x.value_counts()
# Out:
# False    854
# True     737
# Name: quality, dtype: int64

# %%
lb = ['High quality','Low quality']
explode = [0,0.1]
plt.pie(x.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= None)
plt.title('High quality vs Low quality')
plt.legend(x.value_counts())

# %%
sns.catplot(x='quality',data=df ,kind ='count')

# %% [markdown]
# From the chart, most of the wine samples have a quality of 5 and 6 with very few of quality 3 and 8.

# %%
plt.title('Histogram of index vs quality')
plt.hist(data.quality)
plt.ylabel('Index')
plt.xlabel('quality')

# %%
sns.histplot(data= data.quality, kde= True, bins = 20)
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
data_correlation= df.corr()

# %%
data_correlation
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.256737     0.672306
# volatile_acidity          -0.256737          1.000000    -0.551511
# citric_acid                0.672306         -0.551511     1.000000
# residual_sugar             0.114839          0.001336     0.143731
# chlorides                  0.093857          0.061202     0.204294
# free_sulfur_dioxide       -0.150261         -0.014598    -0.057619
# total_sulfur_dioxide      -0.110992          0.074132     0.038593
# density                    0.666876          0.022504     0.364181
# pH                        -0.683788          0.234251    -0.543230
# sulphates                  0.184937         -0.261872     0.313530
# alcohol                   -0.061167         -0.203490     0.109561
# quality                    0.124958         -0.389380     0.224263
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %% [markdown]
# ### Heatmap of the Data_ correlation

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_correlation, annot=True , color= 'k')
# Out:
# <Axes: >

# %% [markdown]
# ## From the Heatmap

# %% [markdown]
# * #### It can be observed that, fixed acidity has a strong positive correlation with citric acid and density with a strong negative correlation between PH.
# * #### volatile acidity has a strong negative correlation with citric acid.
# * #### Residual sugar has a positive correlation with density.
# * #### Chloride has a positive correlation with sulphates.
# * #### Free sulphur dioxide has a strong positive correlation with total sulphur dioxide.
# * #### Density has a strong negative correlation with alcohol.
# * #### PH has a strong negative correlation with fixed acidity and citric acid.
# * #### volatile acidity has a strong negative correlation with quality.
